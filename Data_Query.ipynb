# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Data Science & Data Analysis/Python For Data Analysis/Data Query/Salinan Online Retail Data.csv')
dataset
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# 0       2010-01-04 09:24:00   4.50      12346.0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461773 entries, 0 to 461772
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      461773 non-null  object
#  1   product_code  461773 non-null  object
#  2   product_name  459055 non-null  object
#  3   quantity      461773 non-null  int64
#  4   order_date    461773 non-null  object
#  5   price         461773 non-null  float64
#  6   customer_id   360853 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 24.7+ MB

# %% [markdown]
# # Query data dengan index

# %% [markdown]
# ## Mengambil satu atau beberapa baris tertentu dengan index berupa integer

# %%
#mengambil 1 baris tertentu
dataset.iloc[1]
# Out:
# order_id                        C493411
# product_code                      21539
# product_name    RETRO SPOTS BUTTER DISH
# quantity                             -1
# order_date          2010-01-04 09:43:00
# price                              4.25
# customer_id                     14590.0
# Name: 1, dtype: object

# %%
#mengambil beberapa baris tertentu dengan index berupa list
dataset.iloc[[100,120,150]]
# Out:
#     order_id product_code                     product_name  quantity  \
# 100   493432        22073           RETRO SPOT STORAGE JAR         1
# 120   493433        48188         DOOR MAT WELCOME PUPPIES         2
# 150   493435        37112  YELLOW BIRDS FELT DES FOODCOVER         2
#
#               order_date  price  customer_id
# 100  2010-01-04 12:30:00   3.75      14680.0
# 120  2010-01-04 12:51:00   6.75      14709.0
# 150  2010-01-04 12:57:00   3.75      13206.0

# %%
#mengambil beberapa baris tertentu dengan index berupa range
dataset.iloc[100:121]
# Out:
#     order_id product_code                     product_name  quantity  \
# 100   493432        22073           RETRO SPOT STORAGE JAR         1
# 101   493432        21533        RETRO SPOT LARGE MILK JUG         1
# 102   493432        22072    TEA CUP AND SAUCER RETRO SPOT         2
# 103   493432        21537         RETRO SPOTS PUDDING BOWL         1
# 104   493432        21527    RETRO SPOT TRADITIONAL TEAPOT         5
# 105   493432        21531        RETRO SPOT SUGAR JAM BOWL         2
# 106   493432        21535        RETRO SPOT SMALL MILK JUG         2
# 107   493432        21232   STRAWBERRY CERAMIC TRINKET BOX         7
# 108   493432        21231   SWEETHEART CERAMIC TRINKET BOX         4
# 109   493432        37503  TEA TIME CAKE STAND IN GIFT BOX         2
# 110   493432        21844                   RETRO SPOT MUG         2
# 111   493432        21874                GIN AND TONIC MUG         2
# 112   493433        84991      60 TEATIME FAIRY CAKE CASES        24
# ...

# %%
#mengambil semua baris dari baris tertentu
dataset.iloc[4000:]
# Out:
#        order_id product_code                         product_name  quantity  \
# 4000     494011       47599A                      PINK PARTY BAGS         2
# 4001     494011       84414B  FUSCHIA/GREEN STRIPE WOOLLY BLANKET         1
# 4002     494011       84968A            S/16 VINTAGE ROSE CUTLERY         1
# 4003     494011       85132A         CHARLIE + LOLA BISCUITS TINS         4
# 4004     494011       90038A  GLASS AND PAINTED BEADS BRACELET TO         1
# ...         ...          ...                                  ...       ...
# 461768   539991        21618       4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741                GRAND CHOCOLATECANDLE         4
# 461770   539992        21470        FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258              FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155                RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# ...

# %%
#mengambil semua baris diatas baris tertentu
dataset.iloc[:20]
# Out:
#    order_id product_code                         product_name  quantity  \
# 0    493410      TEST001              This is a test product.         5
# 1   C493411        21539              RETRO SPOTS BUTTER DISH        -1
# 2    493412      TEST001              This is a test product.         5
# 3    493413        21724      PANDA AND BUNNIES STICKER SHEET         1
# 4    493413        84578       ELEPHANT TOY WITH BLUE T-SHIRT         1
# 5    493413        21723        ALPHABET HEARTS STICKER SHEET         1
# 6    493414        21844                       RETRO SPOT MUG        36
# 7    493414        21533            RETRO SPOT LARGE MILK JUG        12
# 8    493414        37508      NEW ENGLAND CERAMIC CAKE SERVER         2
# 9    493414       35001G                 HAND OPEN SHAPE GOLD         2
# 10   493414        21527        RETRO SPOT TRADITIONAL TEAPOT        12
# 11   493414        21531            RETRO SPOT SUGAR JAM BOWL        24
# ...

# %%
#mengambil bari terakhir
dataset.iloc[-1]
# Out:
# order_id                       539992
# product_code                    21155
# product_name    RED RETROSPOT PEG BAG
# quantity                            1
# order_date        2010-12-23 17:41:00
# price                             2.1
# customer_id                       NaN
# Name: 461772, dtype: object

# %%
#mengambil beberapa baris terakhir
dataset.iloc[-6:]
# Out:
#        order_id product_code                     product_name  quantity  \
# 461767   539991        21616  4 PEAR BOTANICAL DINNER CANDLES         1
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# 461767  2010-12-23 16:49:00   1.25          NaN
# 461768  2010-12-23 16:49:00   1.25          NaN
# 461769  2010-12-23 16:49:00   1.45          NaN
# 461770  2010-12-23 17:41:00   3.75          NaN
# 461771  2010-12-23 17:41:00   1.25          NaN
# 461772  2010-12-23 17:41:00   2.10          NaN

# %%
#mengambil semua baris diatas beberapa baris terakhir
dataset.iloc[:-20]
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461748   539990        90112            PINK DOLLY HAIR CLIPS         2
# 461749   539990        21154         RED RETROSPOT OVEN GLOVE         2
# 461750   539990        22966    GINGERBREAD MAN COOKIE CUTTER         1
# 461751   539990        22379          RECYCLING BAG RETROSPOT         1
# 461752   539990        22759     SET OF 3 NOTEBOOKS IN PARCEL         1
#
#                  order_date  price  customer_id
# 0       2010-01-04 09:24:00   4.50      12346.0
# ...

# %% [markdown]
# ## Mengambil satu atau beberapa kolom tertentu dengan index berupa integer

# %%
#mengambil 1 kolom tertentu
dataset.iloc[:,2]
# Out:
# 0                 This is a test product.
# 1                 RETRO SPOTS BUTTER DISH
# 2                 This is a test product.
# 3         PANDA AND BUNNIES STICKER SHEET
# 4          ELEPHANT TOY WITH BLUE T-SHIRT
#                        ...
# 461768     4 WILDFLOWER BOTANICAL CANDLES
# 461769              GRAND CHOCOLATECANDLE
# 461770      FLOWER VINE RAFFIA FOOD COVER
# 461771            FELT FARM ANIMAL RABBIT
# 461772              RED RETROSPOT PEG BAG
# Name: product_name, Length: 461773, dtype: object

# %%
#mengambil beberapa kolom tertentu dengan index lit
dataset.iloc[:,[1,4,6]]
# Out:
#        product_code           order_date  customer_id
# 0           TEST001  2010-01-04 09:24:00      12346.0
# 1             21539  2010-01-04 09:43:00      14590.0
# 2           TEST001  2010-01-04 09:53:00      12346.0
# 3             21724  2010-01-04 09:54:00          NaN
# 4             84578  2010-01-04 09:54:00          NaN
# ...             ...                  ...          ...
# 461768        21618  2010-12-23 16:49:00          NaN
# 461769        72741  2010-12-23 16:49:00          NaN
# 461770        21470  2010-12-23 17:41:00          NaN
# 461771        22258  2010-12-23 17:41:00          NaN
# 461772        21155  2010-12-23 17:41:00          NaN
#
# [461773 rows x 3 columns]

# %%
#mengambil beberapa kolom tertentu dengan index berupa range
dataset.iloc[:,2:7]
# Out:
#                            product_name  quantity           order_date  price  \
# 0               This is a test product.         5  2010-01-04 09:24:00   4.50
# 1               RETRO SPOTS BUTTER DISH        -1  2010-01-04 09:43:00   4.25
# 2               This is a test product.         5  2010-01-04 09:53:00   4.50
# 3       PANDA AND BUNNIES STICKER SHEET         1  2010-01-04 09:54:00   0.85
# 4        ELEPHANT TOY WITH BLUE T-SHIRT         1  2010-01-04 09:54:00   3.75
# ...                                 ...       ...                  ...    ...
# 461768   4 WILDFLOWER BOTANICAL CANDLES         1  2010-12-23 16:49:00   1.25
# 461769            GRAND CHOCOLATECANDLE         4  2010-12-23 16:49:00   1.45
# 461770    FLOWER VINE RAFFIA FOOD COVER         1  2010-12-23 17:41:00   3.75
# 461771          FELT FARM ANIMAL RABBIT         1  2010-12-23 17:41:00   1.25
# 461772            RED RETROSPOT PEG BAG         1  2010-12-23 17:41:00   2.10
#
#         customer_id
# ...

# %%
#mengambil 1kolom terakhir
dataset.iloc[:,-1]
# Out:
# 0         12346.0
# 1         14590.0
# 2         12346.0
# 3             NaN
# 4             NaN
#            ...
# 461768        NaN
# 461769        NaN
# 461770        NaN
# 461771        NaN
# 461772        NaN
# Name: customer_id, Length: 461773, dtype: float64

# %%
#mengambil beberapa kolom terakhir
dataset.iloc[:,-3:]
# Out:
#                  order_date  price  customer_id
# 0       2010-01-04 09:24:00   4.50      12346.0
# 1       2010-01-04 09:43:00   4.25      14590.0
# 2       2010-01-04 09:53:00   4.50      12346.0
# 3       2010-01-04 09:54:00   0.85          NaN
# 4       2010-01-04 09:54:00   3.75          NaN
# ...                     ...    ...          ...
# 461768  2010-12-23 16:49:00   1.25          NaN
# 461769  2010-12-23 16:49:00   1.45          NaN
# 461770  2010-12-23 17:41:00   3.75          NaN
# 461771  2010-12-23 17:41:00   1.25          NaN
# 461772  2010-12-23 17:41:00   2.10          NaN
#
# [461773 rows x 3 columns]

# %% [markdown]
# ## Mengambil satu atau beberapa baris tertentu dengan index non-integer

# %%
dataset_non=dataset.copy()
dataset_non.set_index('order_id',inplace=True)

# %%
#mengambil baris dengan index non integer
dataset_non.loc[['493412']]
# Out:
#          product_code             product_name  quantity           order_date  \
# order_id
# 493412        TEST001  This is a test product.         5  2010-01-04 09:53:00
#
#           price  customer_id
# order_id
# 493412      4.5      12346.0

# %% [markdown]
# ## Mengambil satu atau beberapa kolom tertentu dengan index non-integer

# %%
dataset.loc[:,'product_name']
# Out:
# 0                 This is a test product.
# 1                 RETRO SPOTS BUTTER DISH
# 2                 This is a test product.
# 3         PANDA AND BUNNIES STICKER SHEET
# 4          ELEPHANT TOY WITH BLUE T-SHIRT
#                        ...
# 461768     4 WILDFLOWER BOTANICAL CANDLES
# 461769              GRAND CHOCOLATECANDLE
# 461770      FLOWER VINE RAFFIA FOOD COVER
# 461771            FELT FARM ANIMAL RABBIT
# 461772              RED RETROSPOT PEG BAG
# Name: product_name, Length: 461773, dtype: object

# %%
#mengambil beberapa kolom dengan index non-integer
dataset.loc[:,['order_id','product_code']]
# Out:
#        order_id product_code
# 0        493410      TEST001
# 1       C493411        21539
# 2        493412      TEST001
# 3        493413        21724
# 4        493413        84578
# ...         ...          ...
# 461768   539991        21618
# 461769   539991        72741
# 461770   539992        21470
# 461771   539992        22258
# 461772   539992        21155
#
# [461773 rows x 2 columns]

# %% [markdown]
# # Query data dengan logical expression

# %% [markdown]
# ## Mengambil baris dengan 1 kondisi tertentu

# %%
dataset[dataset['order_id']=='539991']
# Out:
#        order_id product_code                         product_name  quantity  \
# 461757   539991       84029G  KNITTED UNION FLAG HOT WATER BOTTLE         1
# 461758   539991        22970                LONDON BUS COFFEE MUG         2
# 461759   539991        22423             REGENCY CAKESTAND 3 TIER         1
# 461760   539991        21629     SQUARE FLOOR CUSHION VINTAGE RED         1
# 461761   539991        21324         HANGING MEDINA LANTERN SMALL         2
# 461762   539991        22891                 TEA FOR ONE POLKADOT         1
# 461763   539991        22649         STRAWBERRY FAIRY CAKE TEAPOT         1
# 461764   539991        35443       RASTA IN BATH W SPLIFF ASHTRAY         1
# 461765   539991        22111         SCOTTIE DOG HOT WATER BOTTLE         1
# 461766   539991        22802             FAUX FUR CHOCOLATE THROW         1
# 461767   539991        21616      4 PEAR BOTANICAL DINNER CANDLES         1
# ...

# %%
dataset.loc[dataset['order_id']=='539991',['product_code','product_name','quantity']]
# Out:
#        product_code                         product_name  quantity
# 461757       84029G  KNITTED UNION FLAG HOT WATER BOTTLE         1
# 461758        22970                LONDON BUS COFFEE MUG         2
# 461759        22423             REGENCY CAKESTAND 3 TIER         1
# 461760        21629     SQUARE FLOOR CUSHION VINTAGE RED         1
# 461761        21324         HANGING MEDINA LANTERN SMALL         2
# 461762        22891                 TEA FOR ONE POLKADOT         1
# 461763        22649         STRAWBERRY FAIRY CAKE TEAPOT         1
# 461764        35443       RASTA IN BATH W SPLIFF ASHTRAY         1
# 461765        22111         SCOTTIE DOG HOT WATER BOTTLE         1
# 461766        22802             FAUX FUR CHOCOLATE THROW         1
# 461767        21616      4 PEAR BOTANICAL DINNER CANDLES         1
# 461768        21618       4 WILDFLOWER BOTANICAL CANDLES         1
# 461769        72741                GRAND CHOCOLATECANDLE         4

# %% [markdown]
# yang sebenarnya terjadi adalah kita membuat 1 binary array yang berisi nilai <mark>False</mark> untuk semua baris kecuali baris yang memenuhi kondisi tersebut diberi nilai <mark>True</mark>, kemudian menjadikannya non-integer index untuk meng-query data

# %%
dataset['order_id']=='539991'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 461768     True
# 461769     True
# 461770    False
# 461771    False
# 461772    False
# Name: order_id, Length: 461773, dtype: bool

# %%
#alternatif penulisan dataset['order_id]
dataset.loc[dataset.order_id=='539991']
# Out:
#        order_id product_code                         product_name  quantity  \
# 461757   539991       84029G  KNITTED UNION FLAG HOT WATER BOTTLE         1
# 461758   539991        22970                LONDON BUS COFFEE MUG         2
# 461759   539991        22423             REGENCY CAKESTAND 3 TIER         1
# 461760   539991        21629     SQUARE FLOOR CUSHION VINTAGE RED         1
# 461761   539991        21324         HANGING MEDINA LANTERN SMALL         2
# 461762   539991        22891                 TEA FOR ONE POLKADOT         1
# 461763   539991        22649         STRAWBERRY FAIRY CAKE TEAPOT         1
# 461764   539991        35443       RASTA IN BATH W SPLIFF ASHTRAY         1
# 461765   539991        22111         SCOTTIE DOG HOT WATER BOTTLE         1
# 461766   539991        22802             FAUX FUR CHOCOLATE THROW         1
# 461767   539991        21616      4 PEAR BOTANICAL DINNER CANDLES         1
# ...

# %% [markdown]
# namun penulisan <mark>df.order_id</mark> (menggunakan titik) tidak dapat digunakan pada kondisi nama kolom mengandung spasi seperti <mark>df.order id</mark>
# sehingga penulisan <mark>df.['order id']</mark> perlu digunakan dan sifatnya lebih general (berlaku di semua kondisi, dengan atau tanpa spasi sebagai nama/index kolom)

# %% [markdown]
# ## Mengambil beberapa baris dengan beberapa kondisi tertentu

# %% [markdown]
# ### Beberapa kondisi dengan operator & (and)

# %%
dataset[(dataset['product_name'].str.contains('TEA')) & (dataset['quantity']==1)]
# Out:
#        order_id product_code                    product_name  quantity  \
# 253      493442        37333            RETRO "TEA FOR ONE"          1
# 311      493443        21528   DAIRY MAID TRADITIONAL TEAPOT         1
# 337      493443       47566B          TEA TIME PARTY BUNTING         1
# 528      493536        21035     SET/2 RED SPOTTY TEA TOWELS         1
# 576      493536        20747              PICCADILLY TEA SET         1
# ...         ...          ...                             ...       ...
# 461373   539958        22309            TEA COSY RED  STRIPE         1
# 461383   539958        22358          KINGS CHOICE TEA CADDY         1
# 461472   539958        22900  SET 2 TEA TOWELS I LOVE LONDON         1
# 461762   539991        22891            TEA FOR ONE POLKADOT         1
# 461763   539991        22649    STRAWBERRY FAIRY CAKE TEAPOT         1
#
#                  order_date  price  customer_id
# 253     2010-01-04 13:36:00   4.95      13821.0
# ...

# %% [markdown]
# seperti pada 1 kondisi tertentu, pada 2 atau lebih kondisi pun yang sebenarnya terjadi adalah kita membuat binary array untuk setiap kondisi dan mengevaluasinya berdasarkan konsep kombinasi logika

# %%
dataset['product_name'].str.contains('TEA')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 461768    False
# 461769    False
# 461770    False
# 461771    False
# 461772    False
# Name: product_name, Length: 461773, dtype: object

# %%
dataset['quantity']==1
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4          True
#           ...
# 461768     True
# 461769    False
# 461770     True
# 461771     True
# 461772     True
# Name: quantity, Length: 461773, dtype: bool

# %% [markdown]
# ### Beberapa kondisi dengan operator | (or)

# %%
dataset[(dataset['product_name'].str.contains('TEA'))| (dataset['product_name'].str.contains('COFFE'))]
# Out:
#        order_id product_code                   product_name  quantity  \
# 10       493414        21527  RETRO SPOT TRADITIONAL TEAPOT        12
# 12      C493415        21527  RETRO SPOT TRADITIONAL TEAPOT        -3
# 22       493427        79000             MOROCCAN TEA GLASS        12
# 58      C493430        21527  RETRO SPOT TRADITIONAL TEAPOT        -1
# 102      493432        22072  TEA CUP AND SAUCER RETRO SPOT         2
# ...         ...          ...                            ...       ...
# 461653   539986        22302       COFFEE MUG PEARS  DESIGN         5
# 461744   539988       47559B            TEA TIME OVEN GLOVE         2
# 461758   539991        22970          LONDON BUS COFFEE MUG         2
# 461762   539991        22891           TEA FOR ONE POLKADOT         1
# 461763   539991        22649   STRAWBERRY FAIRY CAKE TEAPOT         1
#
#                  order_date  price  customer_id
# 10      2010-01-04 10:28:00   6.95      14590.0
# ...

# %%
dataset['product_name'].str.contains("TEA")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 461768    False
# 461769    False
# 461770    False
# 461771    False
# 461772    False
# Name: product_name, Length: 461773, dtype: object

# %%
dataset['product_name'].str.contains("COFFEE")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 461768    False
# 461769    False
# 461770    False
# 461771    False
# 461772    False
# Name: product_name, Length: 461773, dtype: object

# %% [markdown]
# ### Mengambil beberapa baris dengan kombinasi kondisi and ataupun or

# %%
dataset[(dataset['product_name'].str.contains('TEA')
          | dataset['product_name'].str.contains('COFFEE')) &
        (dataset['quantity']>10)]
# Out:
#        order_id product_code                       product_name  quantity  \
# 10       493414        21527      RETRO SPOT TRADITIONAL TEAPOT        12
# 22       493427        79000                 MOROCCAN TEA GLASS        12
# 112      493433        84991        60 TEATIME FAIRY CAKE CASES        24
# 305      493443        21527      RETRO SPOT TRADITIONAL TEAPOT        12
# 455      493467        84991        60 TEATIME FAIRY CAKE CASES        24
# ...         ...          ...                                ...       ...
# 459159   539654        84946    ANTIQUE SILVER TEA GLASS ETCHED        18
# 459663   539728        22348        TEA BAG PLATE RED RETROSPOT        12
# 460395   539750        22114  HOT WATER BOTTLE TEA AND SYMPATHY       210
# 460927   539920        84946    ANTIQUE SILVER TEA GLASS ETCHED        12
# 460978   539933        84991        60 TEATIME FAIRY CAKE CASES        24
#
#                  order_date  price  customer_id
# ...
